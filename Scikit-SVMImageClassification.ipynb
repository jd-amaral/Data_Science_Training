# %%
import pandas as pd

# %%
mnist_data = pd.read_csv('datasets/02/demos/data/mnist/train.csv')
mnist_data.tail()
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 41995      0       0       0       0       0       0       0       0       0
# 41996      1       0       0       0       0       0       0       0       0
# 41997      7       0       0       0       0       0       0       0       0
# 41998      6       0       0       0       0       0       0       0       0
# 41999      9       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 41995       0  ...         0         0         0         0         0
# 41996       0  ...         0         0         0         0         0
# 41997       0  ...         0         0         0         0         0
# 41998       0  ...         0         0         0         0         0
# 41999       0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 41995         0         0         0         0         0
# 41996         0         0         0         0         0
# 41997         0         0         0         0         0
# 41998         0         0         0         0         0
# 41999         0         0         0         0         0
#
# [5 rows x 785 columns]

# %%
from sklearn.model_selection import train_test_split

features = mnist_data.columns[1:]
X = mnist_data[features]
Y = mnist_data['label']

X_train, X_test, Y_train, Y_test = train_test_split(X/255., Y, test_size=0.1, random_state=0)

# %%
from sklearn.svm import LinearSVC

clf_svm = LinearSVC(penalty='l2', dual=False, tol=1e-5)
clf_svm.fit(X_train, Y_train)
# Out:
# LinearSVC(dual=False, tol=1e-05)

# %%
from sklearn.metrics import accuracy_score

y_pred_svm = clf_svm.predict(X_test)
acc_svm = accuracy_score(Y_test, y_pred_svm)
print('SVM accuracy: ', acc_svm)
# Out:
# SVM accuracy:  0.9102380952380953

# %%
clf_svm = LinearSVC(penalty='l1', dual=False, tol=1e-4)
clf_svm.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 clf_svm = LinearSVC(penalty='l1', dual=False, tol=1e-4)
# ----> 2 clf_svm.fit(X_train, Y_train)
#
# File c:\Users\JAmaral5\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JAmaral5\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_classes.py:321, in LinearSVC.fit(self, X, y, sample_weight)
#     315 self.classes_ = np.unique(y)
#     317 _dual = _validate_dual_parameter(
#     318     self.dual, self.loss, self.penalty, self.multi_class, X
#     319 )
# --> 321 self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#     322     X,
#     323     y,
#     324     self.C,
#     325     self.fit_intercept,
#     326     self.intercept_scaling,
#     327     self.class_weight,
#     328     self.penalty,
#     329     _dual,
#     330     self.verbose,
#     331     self.max_iter,
#     332     self.tol,
#     333     self.random_state,
#     334     self.multi_class,
#     335     self.loss,
#     336     sample_weight=sample_weight,
#     337 )
#     338 # Backward compatibility: _fit_liblinear is used both by LinearSVC/R
#     339 # and LogisticRegression but LogisticRegression sets a structured
#     340 # `n_iter_` attribute with information about the underlying OvR fits
#     341 # while LinearSVC/R only reports the maximum value.
#     342 self.n_iter_ = n_iter_.max().item()
#
# File c:\Users\JAmaral5\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:1230, in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#    1227 sample_weight = _check_sample_weight(sample_weight, X, dtype=np.float64)
#    1229 solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# -> 1230 raw_coef_, n_iter_ = liblinear.train_wrap(
#    1231     X,
#    1232     y_ind,
#    1233     sp.issparse(X),
#    1234     solver_type,
#    1235     tol,
#    1236     bias,
#    1237     C,
#    1238     class_weight_,
#    1239     max_iter,
#    1240     rnd.randint(np.iinfo("i").max),
#    1241     epsilon,
#    1242     sample_weight,
#    1243 )
#    1244 # Regarding rnd.randint(..) in the above signature:
#    1245 # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#    1246 # on 32-bit platforms, we can't get to the UINT_MAX limit that
#    1247 # srand supports
#    1248 n_iter_max = max(n_iter_)
#
# KeyboardInterrupt:

# %%
y_pred_svm = clf_svm.predict(X_test)
acc_svm = accuracy_score(Y_test, y_pred_svm)
print('SVM accuracy: ', acc_svm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y_pred_svm = clf_svm.predict(X_test)
#       2 acc_svm = accuracy_score(Y_test, y_pred_svm)
#       3 print('SVM accuracy: ', acc_svm)
#
# File c:\Users\JAmaral5\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File c:\Users\JAmaral5\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:353, in LinearClassifierMixin.decision_function(self, X)
#     350 xp, _ = get_namespace(X)
#     352 X = validate_data(self, X, accept_sparse="csr", reset=False)
# --> 353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# AttributeError: 'LinearSVC' object has no attribute 'coef_'

# %%
from sklearn.model_selection import GridSearchCV

penalties = ['l1', 'l2']
tolerances = [1e-3, 1e-4, 1e-5]

param_grid = {
    'penalty': penalties,
    'tol': tolerances
}

grid_search = GridSearchCV(LinearSVC(dual=False), param_grid, cv=3)
grid_search.fit(X_train, Y_train)

grid_search.best_params_
